# %% [raw]
# Importing requried libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random as rnd

# %% [raw]
# Fetching data for analysis.

# %%
df = pd.read_csv("../data/raw/creditcard.csv")

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
fraud_transactions   = df[df['Class'] == 1]
genuine_transactions = df[df['Class'] == 0]

print("Total number of record              : {}".format(df.shape[0]))
print("Total number of features in dataset : {}".format(df.shape[1]))
print("Total number of positive cases      : {}".format(fraud_transactions.shape[0]))
print("Percentage of positive cases        : {}".format(100 * df[df['Class'] == 1].shape[0]/df.shape[0]))
print("Outlier fraction                    : {}".format(len(fraud_transactions)/len(genuine_transactions)))
fig = plt.figure(figsize = (10,12))
sns.countplot(df["Class"])
# Out:
# Total number of record              : 284807
# Total number of features in dataset : 31
# Total number of positive cases      : 492
# Percentage of positive cases        : 0.1727485630620034
# Outlier fraction                    : 0.0017304750013189597
# C:\Users\chava\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %% [raw]
# As we can see, the data is highly imbalanced and less than 1 percent of records are fraudulent. Any model trained on this will have high bias towards genuine transactions.

# %% [raw]
# Details of amount cloumn in fraudulent transactions

# %%
fraud_transactions["Amount"].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [raw]
# Details of amount cloumn in geniune transactions

# %%
genuine_transactions["Amount"].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [raw]
# Mean for fraudulent transactions is more then that of genuine transactions

# %%
correlation_matrix = df.corr()
fig = plt.figure(figsize = (10,12))
sns.heatmap(correlation_matrix, vmax = 0.8, square = True)
#plt.show()
# Out:
# <AxesSubplot:>

# %% [raw]
# Plotting histogram for entire data

# %%
#Function to generate a random color
def getRandomColor():
    r = rnd.randint(0,255)
    g = rnd.randint(0,255)
    b = rnd.randint(0,255)
    print((r,g,b))
    return (r,g,b)

def plotHistograms(df, features):
    for feature in features:
        f, axis = plt.subplots(1,1, figsize = (9,4))
        input_distribution_data = df[feature]
        sns.histplot(input_distribution_data, ax = axis,  kde = True)

# %%
plotHistograms(df, df.columns)
# Out:
# C:\Users\chava\AppData\Local\Temp\ipykernel_13588\360410850.py:11: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f, axis = plt.subplots(1,1, figsize = (9,4))

# %% [raw]
# We will implement a Random forest classifier.

# %%
#pip install sklearn
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 7.2/7.2 MB 7.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 307.0/307.0 KB 9.3 MB/s eta 0:00:00
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=75aa3d9d4677e05c6338670783bc084c171bad615c53cff82a33db49e50c6e5e
#   Stored in directory: c:\users\chava\appdata\local\pip\cache\wheels\e4\7b\98\b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
scaler = MinMaxScaler()
X = df.drop(['Class'], axis =1)
X = scaler.fit_transform(X.to_numpy())

pca = PCA(n_components = 2)
pca_features = pca.fit_transform(X)

# %%
genuine_cases = pca_features[df[df['Class'] == 0].index]
fraud_cases = pca_features[df[df['Class'] == 1].index]

# %%
fraud_cases.shape
# Out:
# (492, 1)

# %%
plt.scatter(genuine_cases[:,0],genuine_cases[:,1],color='red')
plt.scatter(fraud_cases[:,0],fraud_cases[:,1],color='blue')
plt.show()
